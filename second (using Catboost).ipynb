# %%
import pandas as pd

df = pd.read_csv('train.csv')
df.head()
# Out:
#    ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0       1     39353   85475         117961         118300         123472
# 1       1     17183    1540         117961         118343         123125
# 2       1     36724   14457         118219         118220         117884
# 3       1     36135    5396         117961         118343         119993
# 4       1     42680    5905         117929         117930         119569
#
#    ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0      117905            117906       290919     117908
# 1      118536            118536       308574     118539
# 2      117879            267952        19721     117880
# 3      118321            240983       290919     118322
# 4      119323            123932        19793     119325

# %%
x = df.drop('ACTION', axis=1)
y = df.ACTION

# %%
cat_features = list(range(0, len(x.columns)))
print(cat_features)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
print('Label: {}'.format(set(y)))
print('Zero % = {} %\nOne % = {} %'.format((len(y) - sum(y))*100/len(y), sum(y)*100/len(y)))
# Out:
# Label: {0, 1}
# Zero % = 5.789007903811529 %
# One % = 94.21099209618848 %

# %%
from catboost import CatBoostClassifier

model = CatBoostClassifier(iterations=500)
model.fit(x, y, cat_features=cat_features, verbose=100)
# Out:
# Learning rate set to 0.086314
# 0:	learn: 0.5952566	total: 89ms	remaining: 44.4s
# 100:	learn: 0.1461604	total: 2.98s	remaining: 11.8s
# 200:	learn: 0.1387989	total: 6.31s	remaining: 9.38s
# 300:	learn: 0.1330055	total: 9.72s	remaining: 6.43s
# 400:	learn: 0.1277795	total: 13.2s	remaining: 3.26s
# 499:	learn: 0.1224644	total: 16.8s	remaining: 0us

# %%
from catboost import Pool
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=0)

train_pool = Pool(
                    data = x_train,
                    label = y_train,
                    cat_features = cat_features
)

val_pool = Pool(
                    data = x_val,
                    label = y_val,
                    cat_features = cat_features
)

# %%
model = CatBoostClassifier(
                            iterations=200,
                            learning_rate=0.03,
                            custom_loss=['AUC', 'Accuracy'],
                            eval_metric='AUC',
#                             early_stopping_rounds=20
)

model.fit(
            train_pool,
            eval_set = val_pool,
            verbose = False,
            plot = True
)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))

# %%
print(model.predict_proba(x_val))
# Out:
# [[0.03126069 0.96873931]
#  [0.02267694 0.97732306]
#  [0.01142188 0.98857812]
#  ...
#  [0.04158451 0.95841549]
#  [0.02799489 0.97200511]
#  [0.01945732 0.98054268]]

# %%
import matplotlib.pyplot as plt
from catboost.utils import get_roc_curve, get_fpr_curve, get_fnr_curve

curve = get_roc_curve(model, val_pool)
(fpr, tpr, thresholds) = curve
(thresholds, fpr) = get_fpr_curve(curve=curve)
(thresholds, fnr) = get_fnr_curve(curve=curve)

# %%
plt.figure(figsize=(16, 8))
style = {'alpha': 0.5, 'lw':2}

plt.plot(thresholds, fpr, color = 'blue', label = 'FPR', **style)
plt.plot(thresholds, fnr, color = 'green', label = 'FNR', **style)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.grid(True)
plt.xlabel('Threshold', fontsize=16)
plt.ylabel('Error Rate', fontsize=16)
plt.title('FPR-FNR curves', fontsize=20)
plt.legend(loc = 'lower left', fontsize=16)

# %%
from catboost.utils import select_threshold

# print(select_threshold(model, val_pool, FNR=0.01))
print(select_threshold(model, val_pool, FPR=0.03))
# Out:
# 0.9836392204844719

# %% [markdown]
# setting margine as 0.95

# %%
prediction = model.predict_proba(x_val)
print(type(prediction))
# Out:
# <class 'numpy.ndarray'>

# %%
def predict_this(model, x):
    prediction = model.predict_proba(x)
#     margin = 0.98
    y_pred = [prediction[i][1] for i in range(len(prediction))]
555, 0.5779977113500475, 0.6416486567605597, 0.9801533137972722, 0.9733638788400113, 0.9491284184332507, 0.9846805911702738, 0.9529286288204214, 0.9554022352901471, 0.9636763795902474, 0.9888075727990613, 0.9868048658856434, 0.9897557306526445, 0.9275064673233184, 0.9777921146505889, 0.9802756221141883, 0.6753874067330914, 0.9873639923053042, 0.960666617004216, 0.9674131466184287, 0.9844840100403749, 0.9752865573224703, 0.9457621194218104, 0.9624156892545054, 0.9879455430021323, 0.9628933323493386, 0.9901283262532331, 0.9849666474982645, 0.9871914176204407, 0.9482053948164143, 0.973241764724088, 0.9721080838509571, 0.9305428697994821, 0.9887097189171045, 0.9759568809623469, 0.986547497503064, 0.9891065757590279, 0.8986609585963652, 0.9915320619582043, 0.9793564694299187, 0.985435758669249, 0.990649855671989, 0.9811115194115413, 0.9478915980716276, 0.9907686296728052, 0.5464826126204035, 0.8426242105975337, 0.9890911274784819, 0.5349220509263668, 0.9523078134105143, 0.9735295364470402, 0.9862382172875792, 0.9747292108593575, 0.972711690217011, 0.9763367028213007, 0.8134169862973432, 0.9772291600356354, 0.6057638346011048, 0.9556368082665202, 0.9894413168324273, 0.799771755840241, 0.9666460570702012, 0.9763661983695363, 0.9893063423962437, 0.9834004383719988, 0.9672441890919116, 0.6175806317679335, 0.9735719329673082, 0.9722619954403081, 0.9587455817764917, 0.9799247989191621, 0.8953914185492827, 0.9848461566360138, 0.9916495923867447, 0.9850657241820386, 0. ...

# %%
print(len(y_pred))
print(len(prediction))
# Out:
# 6554
# 6554

# %%
from sklearn import metrics

# %%
fpr, tpr, thresholds = metrics.roc_curve(y_val, y_pred, pos_label=1)
auc = metrics.auc(fpr,tpr)
auc
# Out:
# 0.8955058998897251

# %%
test_df = pd.read_csv("test.csv")
test_x = test_df.drop(["id"], axis = 1)
test_x.head()
# Out:
#    RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  ROLE_TITLE  \
# 0     78766   72734         118079         118080         117878      117879
# 1     40644    4378         117961         118327         118507      118863
# 2     75443    2395         117961         118300         119488      118172
# 3     43219   19986         117961         118225         118403      120773
# 4     42093   50015         117961         118343         119598      118422
#
#    ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0            118177        19721     117880
# 1            122008       118398     118865
# 2            301534       249618     118175
# 3            136187       118960     120774
# 4            300136       118424     118425

# %%
model1 = CatBoostClassifier(
                            iterations=1000,
                            learning_rate=0.03,
                            eval_metric='AUC',
)

model1.fit(x, y, cat_features=cat_features, verbose=False, plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))

# %%
pool = Pool(
             data = x_val,
             label = y_val,
             cat_features = cat_features
)
print(select_threshold(model1, train_pool, FPR=0))
print(select_threshold(model1, train_pool, FNR=0.01))
# Out:
# 0.9869208703406526
# 0.7460835231630973

# %%
y_pred = predict_this(model1, test_x)
output = pd.DataFrame({'id': test_df.id, 'ACTION': y_pred})
output.to_csv('my_submission_1.csv', index=False)
